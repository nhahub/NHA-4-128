# %%
# ==========================================
# 1. System & Utilities (System Operations)
# ==========================================
import os
import cv2
import itertools

# ==========================================
# 2. Data Handling (Data Manipulation)
# ==========================================
import numpy as np
import pandas as pd

# ==========================================
# 3. Visualization (Plotting Graphs)
# ==========================================
import matplotlib.pyplot as plt
import seaborn as sns

# ==========================================
# 4. Machine Learning & Metrics (Scikit-Learn)
# ==========================================
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# ==========================================
# 5. Deep Learning - Core (TensorFlow)
# ==========================================
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# ==========================================
# 6. Deep Learning - Models & Layers
# ==========================================
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import (Conv2D, MaxPooling2D, Flatten, Dense, 
                                     Dropout, BatchNormalization)
from tensorflow.keras.applications import MobileNetV2

# ==========================================
# 7. Deep Learning - Callbacks (Training Control)
# ==========================================
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Success Message
print("✅ Libraries Imported Successfully!")

DATASET_PATH = '/kaggle/input/datasets/hasnainjaved/melanoma-skin-cancer-dataset-of-10000-images/melanoma_cancer_dataset'
test_path = os.path.join(DATASET_PATH, "test")
train_path = os.path.join(DATASET_PATH, "train") 
print(f"Train path exists: {os.path.exists(train_path)}")
print(f"Test path exists: {os.path.exists(test_path)}")


# Get class names (folder names) in the training directory
classes = os.listdir(train_path)  # e.g., ['benign', 'malignant']

# Count the number of images in each class
image_counts = {}
for c in classes:
    class_path = os.path.join(train_path, c)
    image_counts[c] = len(os.listdir(class_path))  # Count files in the folder

# Print the number of images per class
print("Number of images per class:", image_counts)

# Plot a bar chart to visualize the distribution of images per class
plt.figure(figsize=(6,4))
plt.bar(image_counts.keys(), image_counts.values(), color=['skyblue', 'salmon'])
plt.title("Number of Images per Class")
plt.xlabel("Class")
plt.ylabel("Number of Images")
plt.show()




img_size = (224,224)
batch_size = 32

# --- Data Augmentation + Rescaling for training ---
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest',
    validation_split=0.2  
)

# --- Training Generator ---
train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='binary',
    subset='training',     
    shuffle=True
)

# --- Validation Generator ---
val_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='binary',
    subset='validation',    
    shuffle=False
)


# Show Samples From each class
def show_sample_images(folder_path, title, n=5):
  
    if not os.path.exists(folder_path):
        print(f"Directory not found: {folder_path}")
        return

    files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))][:n]

    plt.figure(figsize=(15, 3))
    for i, f in enumerate(files):
        img_path = os.path.join(folder_path, f)
        img = cv2.imread(img_path)
        if img is None:
            continue
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        plt.subplot(1, n, i+1)
        plt.imshow(img)
        plt.title(f)
        plt.axis('off')
    plt.suptitle(title)
    plt.show()

# SHOW SAMPLES

folders = [
    (os.path.join(train_path, "benign"), "Train - Benign"),
    (os.path.join(train_path, "malignant"), "Train - Malignant"),
    (os.path.join(test_path, "benign"), "Test - Benign"),
    (os.path.join(test_path, "malignant"), "Test - Malignant"),
]

for folder_path, title in folders:
    show_sample_images(folder_path, title, n=5)

# Histogram Equalization / CLAHE Algorithm Definition
def apply_clahe(img):
    img_yuv = cv2.cvtColor(img, cv2.COLOR_RGB2YUV)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
    img_yuv[:,:,0] = clahe.apply(img_yuv[:,:,0])
    img = cv2.cvtColor(img_yuv, cv2.COLOR_YUV2RGB)
    return img

# Show Difference
folder_benign_train = os.path.join(train_path, "benign")


if len(os.listdir(folder_benign_train)) > 0:
    img_name = os.listdir(folder_benign_train)[0]  
    img_path_clahe_test = os.path.join(folder_benign_train, img_name)
    img_org = cv2.imread(img_path_clahe_test)
    img_org = cv2.cvtColor(img_org, cv2.COLOR_BGR2RGB)

    img_clahe = apply_clahe(img_org)

   
    plt.figure(figsize=(12,6))
    plt.subplot(1, 2, 1)
    plt.imshow(img_org)
    plt.axis('off')
    plt.title("Original Image")

    plt.subplot(1, 2, 2)
    plt.imshow(img_clahe)
    plt.axis('off')
    plt.title("After CLAHE")
    plt.show()
else:
    print("No images found to test CLAHE.")

# =====================================================
# 2. EXPERIMENT 1 - MODEL (Vanella CNN).
# =====================================================


# Initialize the Sequential model
model = tf.keras.models.Sequential()

model.add(tf.keras.Input(shape=(224, 224, 3))) #input layer
model.add(tf.keras.layers.Conv2D(32, (3, 3), strides=(1, 1), padding='same', activation='relu')) 
model.add(tf.keras.layers.MaxPooling2D((2, 2))) # Reduces spatial dimensions by half (downsampling)

# --- Block 2: Mid-Level Features ---
# Increasing filters to 64 to capture more complex patterns.
model.add(tf.keras.layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.Dropout(0.25)) # Dropout drops 25% of neurons randomly to prevent overfitting

# --- Block 3: High-Level Features ---
# Increasing filters to 128.
model.add(tf.keras.layers.Conv2D(128, (3, 3), strides=(1, 1), padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.Dropout(0.3)) # Increased dropout rate as the model gets deeper

# --- Block 4: Very Complex Features (Added for higher accuracy) ---
# 256 filters to capture the most abstract features of the skin lesion.
model.add(tf.keras.layers.Conv2D(256, (3, 3), strides=(1, 1), padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.Dropout(0.3)) # Higher dropout to strongly combat overfitting in deep layers

# --- Classification Head ---
model.add(tf.keras.layers.Flatten()) # Converts the 3D feature maps into a 1D vector

# Fully connected layer for decision making
model.add(tf.keras.layers.Dense(256, activation='relu')) 
model.add(tf.keras.layers.Dropout(0.5)) # 50% dropout in the dense layer is standard practice

# Output Layer

# Sigmoid activation is used because we have a binary classification task (0 or 1)
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

model.compile(
    loss='binary_crossentropy',  # Standard loss function for binary classification tasks
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), # Using Adam optimizer with a low initial learning rate for stability
    metrics=['accuracy']         # Tracking accuracy during training
)

# Display the model structure
model.summary()


# --- 2. Setup Callbacks (Training Helpers) ---

# ModelCheckpoint: Saves the best version of the model based on validation accuracy.
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'best_vanilla_model.h5',     # Filename to save the best model
    monitor='val_accuracy',      # Metric to monitor
    save_best_only=True,         # Only save if the current model is better than previous best
    mode='max',                  # We want to maximize accuracy
    verbose=1
)

# EarlyStopping: Stops training if validation loss doesn't improve for a set number of epochs.
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',          # Metric to monitor for stopping
    patience=5,                 # Number of epochs to wait before stopping
    restore_best_weights=True,   # Restore model weights to the best epoch found
    verbose=1
)

# ReduceLROnPlateau: Reduces learning rate if validation loss plateaus (stops improving).
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,                  # Factor by which the learning rate will be reduced (new_lr = lr * factor)
    patience=5,                  # Number of epochs to wait before reducing LR
    min_lr=0.00001,              # Lower bound for the learning rate
    verbose=1
)
# Combine callbacks into a list
callbacks_list = [checkpoint, early_stopping, reduce_lr]

print("Starting Training...")

history_ex1 = model.fit(
    train_generator,
    epochs=50, 
    validation_data=val_generator,
    callbacks=callbacks_list
)

print("Training Finished.")


model.save('/kaggle/working/best_vanilla_model.h5')
print("Model saved successfully!")

val_generator.shuffle = False
val_loss, val_acc = model.evaluate(val_generator, verbose=1)
print(val_loss, val_acc)


# True labels
true_labels = val_generator.classes

# Predicted probabilities
pred_probs = model.predict(val_generator)

# Convert probabilities → labels
pred_labels = (pred_probs > 0.5).astype("int32")

# Confusion Matrix
cm = confusion_matrix(true_labels, pred_labels)

# Plot Heatmap
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Benign','Malignant'],
            yticklabels=['Benign','Malignant'])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix Heatmap")
plt.show()

# Classification Report
print(classification_report(true_labels, pred_labels, target_names=['Benign','Malignant']))


plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history_ex1.history['accuracy'])
plt.plot(history_ex1.history['val_accuracy'])
plt.legend(['Train','Val'])
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(history_ex1.history['loss'])
plt.plot(history_ex1.history['val_loss'])
plt.legend(['Train','Val'])
plt.title('Loss')

plt.show()

# =====================================================
# 2.2 EXPERIMENT 2 -  IMPROVED MODEL (Vanella CNN).
# =====================================================


image_size = (150,150,3)

model_2 = Sequential()
model_2.add(Conv2D(64, (3,3), strides=(1, 1), padding='same', activation="relu", input_shape=image_size))
model_2.add(MaxPooling2D())

model_2.add(Conv2D(128, (3,3), strides=(1, 1), padding='same', activation="relu"))
model_2.add(MaxPooling2D())
model_2.add(Dropout(0.2))

model_2.add(Conv2D(256, (3,3), strides=(1, 1), padding='same', activation="relu"))
model_2.add(MaxPooling2D())
model_2.add(Dropout(0.2))

model_2.add(Conv2D(512, (3,3), strides=(1, 1), padding='same', activation="relu"))
model_2.add(MaxPooling2D())
model_2.add(Dropout(0.2))

model_2.add(Flatten())
model_2.add(Dense(128, activation="relu"))
model_2.add(Dropout(0.15))

model_2.add(Dense(1, activation="sigmoid"))

model_2.compile(loss="binary_crossentropy",
                optimizer='adam',
                metrics=["accuracy"])

model_2.summary()



checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'best_cnn_ex2_model.h5',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=5,
    min_lr=0.00001,
    verbose=1
)

callbacks_list = [checkpoint, early_stopping, reduce_lr]

train_datagen_2 = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest',
    validation_split=0.2
)

train_generator_2 = train_datagen_2.flow_from_directory(
    train_path,
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary',
    subset='training',
    shuffle=True
)

val_generator_2 = train_datagen_2.flow_from_directory(
    train_path,
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary',
    subset='validation',
    shuffle=False
)


# ✅ BUG FIX 1: model_2.fit() instead of model.fit()

history_ex2 = model_2.fit(
    train_generator_2,      # ✅
    epochs=50,
    validation_data=val_generator_2,  # ✅
    callbacks=callbacks_list
)

train_acc = history_ex2.history['accuracy']
train_loss = history_ex2.history['loss']

val_acc = history_ex2.history['val_accuracy']
val_loss = history_ex2.history['val_loss']


index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
 
index_acc = np.argmax(val_acc)
val_highest = val_acc[index_acc]

Epochs = [i+1 for i in range(len(train_acc))]

loss_label = f'Best epochs = {str(index_loss +1)}'
acc_label = f'Best epochs = {str(index_acc + 1)}'



#Training history

plt.figure(figsize= (20,8))
plt.style.use('fivethirtyeight')

plt.subplot(1,2,1)
plt.plot(Epochs , train_loss , 'r' , label = 'Training Loss')
plt.plot(Epochs , val_loss , 'g' , label = 'Validation Loss')
plt.scatter(index_loss + 1 , val_lowest , s = 150 , c = 'blue',label = loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1,2,2)
plt.plot(Epochs , train_acc , 'r' , label = 'Training Accuracy')
plt.plot(Epochs , val_acc , 'g' , label = 'Validation Accuracy')
plt.scatter(index_acc + 1 , val_highest , s = 150 , c = 'blue',label = acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout
plt.show();


# ========================================================
# 1️⃣ SMART SETUP (Fixing the Path & Size automatically)
# ========================================================

# Get the correct path from your existing generator
# (Since val_generator works, we copy its path)
correct_path = val_generator.directory
print(f"✅ Using dataset path: {correct_path}")

test_datagen = ImageDataGenerator(rescale=1./255)

# Create the temporary generator with the CORRECT path and size (150x150)
temp_generator = test_datagen.flow_from_directory(
    correct_path,            # <--- Using the detected path
    target_size=(150, 150),  # Fixed size for Model 2
    batch_size=32,
    class_mode='binary',
    shuffle=False            # Important: No shuffling
)

# ========================================================
# 2️⃣ PREDICT & PLOT
# ========================================================
# Get labels
true_labels = temp_generator.classes

# Predict using Model 2
print("Predicting...")
pred_probs = model_2.predict(temp_generator, verbose=1)
pred_labels = (pred_probs > 0.5).astype("int32")

# Plot Heatmap
cm = confusion_matrix(true_labels, pred_labels)

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens',
            xticklabels=['Benign','Malignant'],
            yticklabels=['Benign','Malignant'])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix Heatmap (Model 2)")
plt.show()

# Print Report
print(classification_report(true_labels, pred_labels, target_names=['Benign','Malignant']))

# =====================================================
# 3. EXPERIMENT 3 –   RETRAINED MODEL (MobileNetV2)
# =====================================================

# Create Model Structure
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)
class_count = len(list(train_generator.class_indices.keys())) # Corrected to train_generator


# Load the MobileNetV2 model with pre-trained weights, excluding the top fully connected layers
base_model = MobileNetV2(include_top= False, weights= "imagenet", input_shape= img_shape, pooling= 'max')

# Freeze the base model layers
base_model.trainable = False

# Build the model
model_3 = Sequential([
    base_model,
    BatchNormalization(axis= -1, momentum= 0.99, epsilon= 0.001),
    Dense(512, activation='relu'),  # Add a dense layer
    Dropout(0.5),  # Add dropout for regularization
    Dense(1, activation='sigmoid')  # ✅ BUG FIX 2: 1 instead of class_count for binary classification
])

# Compile the model
model_3.compile(optimizer='adam',
              loss='binary_crossentropy',  # ✅ BUG FIX 3: removed the leading space
              metrics=['accuracy'],
              run_eagerly=True) 

# Print model summary
model_3.summary()

early_stopping = EarlyStopping(
    monitor='val_loss',    
    patience=5,            
    restore_best_weights=True,  
    verbose=1
)

# ✅ BUG FIX 4: model_3.fit() instead of model.fit()
history_ex3 = model_3.fit(
    train_generator,
    validation_data=val_generator,
    epochs=20,
    callbacks=[early_stopping] )

model_3.save('/kaggle/working/MobileNetV2_model.h5')
print("Model saved successfully!")

import matplotlib.pyplot as plt
import numpy as np


train_acc = history_ex3.history['accuracy']
train_loss = history_ex3.history['loss']

val_acc = history_ex3.history['val_accuracy']
val_loss = history_ex3.history['val_loss']

# حساب أفضل Epoch
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]

index_acc = np.argmax(val_acc)
val_highest = val_acc[index_acc]

Epochs = [i+1 for i in range(len(train_acc))]

loss_label = f'Best epochs = {str(index_loss +1)}'
acc_label = f'Best epochs = {str(index_acc + 1)}'

plt.figure(figsize= (20,8))
plt.style.use('fivethirtyeight')

plt.subplot(1,2,1)
plt.plot(Epochs , train_loss , 'r' , label = 'Training Loss')
plt.plot(Epochs , val_loss , 'g' , label = 'Validation Loss')
plt.scatter(index_loss + 1 , val_lowest , s = 150 , c = 'blue', label = loss_label)
plt.title('Training and Validation Loss (Model 3)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1,2,2)
plt.plot(Epochs , train_acc , 'r' , label = 'Training Accuracy')
plt.plot(Epochs , val_acc , 'g' , label = 'Validation Accuracy')
plt.scatter(index_acc + 1 , val_highest , s = 150 , c = 'blue', label = acc_label)
plt.title('Training and Validation Accuracy (Model 3)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()




# Reset generator to ensure alignment
val_generator.reset()

# Get Class Names
class_names = list(val_generator.class_indices.keys())

# Make Predictions using model_3
print("Generating predictions...")
y_pred_probs = model_3.predict(val_generator, verbose=1)

# Handle Binary (Sigmoid) vs Multi-class (Softmax)
if y_pred_probs.shape[1] == 1:
    # Binary Classification (Sigmoid)
    y_pred = (y_pred_probs > 0.5).astype("int32").flatten()
else:
    # Multi-class Classification (Softmax)
    y_pred = np.argmax(y_pred_probs, axis=1)

# Get True Labels
y_true = val_generator.classes

# 2️⃣ Calculate Metrics 
# ------------------------------------------------
# Calculate Overall Accuracy
accuracy = accuracy_score(y_true, y_pred)
print(f"\n✅ Model Accuracy: {accuracy * 100:.2f}%")

# Print Detailed Classification Report
print("\n📊 Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))

# 3️⃣ Plot Confusion Matrix as Heatmap 
# ------------------------------------------------
# Compute Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

# Plotting
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Oranges', 
            xticklabels=class_names, 
            yticklabels=class_names,
            annot_kws={"size": 14}) # Font size for numbers

plt.xlabel('Predicted Label', fontsize=12)
plt.ylabel('True Label', fontsize=12)
plt.title(f'Confusion Matrix Heatmap\nAccuracy: {accuracy*100:.2f}%', fontsize=15)
plt.show()
# Out:
# 2026-04-06 14:36:37.205471: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775486197.449377      25 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775486197.516357      25 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775486198.046858      25 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775486198.046900      25 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775486198.046903      25 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775486198.046906      25 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ✅ Libraries Imported Successfully!
# Train path exists: True
# Test path exists: True
# Number of images per class: {'benign': 5000, 'malignant': 4605}
# Found 7684 images belonging to 2 classes.
# Found 1921 images belonging to 2 classes.
# I0000 00:00:1775486236.528317      25 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1775486236.534381      25 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 28, 28, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 50176)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │    12,845,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,233,985 (50.48 MB)
#  Trainable params: 13,233,985 (50.48 MB)
#  Non-trainable params: 0 (0.00 B)
# Starting Training...
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775486241.461726      92 service.cc:152] XLA service 0x787654009f40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1775486241.461763      92 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1775486241.461767      92 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1775486241.977728      92 cuda_dnn.cc:529] Loaded cuDNN version 91002
#   2/241 ━━━━━━━━━━━━━━━━━━━━ 20s 84ms/step - accuracy: 0.5703 - loss: 1.1700
# I0000 00:00:1775486249.859738      92 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 115/241 ━━━━━━━━━━━━━━━━━━━━ 1:03 502ms/step - accuracy: 0.5500 - loss: 0.7875
# 2026-04-06 14:38:28.594340: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-06 14:38:28.736632: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - accuracy: 0.5888 - loss: 0.7146
# Epoch 1: val_accuracy improved from -inf to 0.70953, saving model to best_vanilla_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 168s 653ms/step - accuracy: 0.5891 - loss: 0.7142 - val_accuracy: 0.7095 - val_loss: 0.5626 - learning_rate: 1.0000e-04
# Epoch 2/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.7999 - loss: 0.4478
# Epoch 2: val_accuracy improved from 0.70953 to 0.82509, saving model to best_vanilla_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 104s 430ms/step - accuracy: 0.8000 - loss: 0.4477 - val_accuracy: 0.8251 - val_loss: 0.4474 - learning_rate: 1.0000e-04
# Epoch 3/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.8431 - loss: 0.3680
# Epoch 3: val_accuracy improved from 0.82509 to 0.84539, saving model to best_vanilla_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 105s 437ms/step - accuracy: 0.8431 - loss: 0.3680 - val_accuracy: 0.8454 - val_loss: 0.4137 - learning_rate: 1.0000e-04
# Epoch 4/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.8545 - loss: 0.3408
# Epoch 4: val_accuracy improved from 0.84539 to 0.86674, saving model to best_vanilla_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 103s 426ms/step - accuracy: 0.8546 - loss: 0.3408 - val_accuracy: 0.8667 - val_loss: 0.3603 - learning_rate: 1.0000e-04
# Epoch 5/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.8740 - loss: 0.3122
# Epoch 5: val_accuracy improved from 0.86674 to 0.86882, saving model to best_vanilla_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 104s 432ms/step - accuracy: 0.8740 - loss: 0.3122 - val_accuracy: 0.8688 - val_loss: 0.3332 - learning_rate: 1.0000e-04
# Epoch 6/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.8727 - loss: 0.3093
# Epoch 6: val_accuracy improved from 0.86882 to 0.87402, saving model to best_vanilla_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 104s 430ms/step - accuracy: 0.8727 - loss: 0.3093 - val_accuracy: 0.8740 - val_loss: 0.3415 - learning_rate: 1.0000e-04
# Epoch 7/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.8648 - loss: 0.3207
# Epoch 7: val_accuracy did not improve from 0.87402
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 101s 421ms/step - accuracy: 0.8648 - loss: 0.3207 - val_accuracy: 0.8647 - val_loss: 0.3297 - learning_rate: 1.0000e-04
# Epoch 8/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.8743 - loss: 0.2937
# Epoch 8: val_accuracy improved from 0.87402 to 0.88444, saving model to best_vanilla_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 103s 427ms/step - accuracy: 0.8744 - loss: 0.2937 - val_accuracy: 0.8844 - val_loss: 0.3060 - learning_rate: 1.0000e-04
# Epoch 9/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.8793 - loss: 0.2913
# Epoch 9: val_accuracy did not improve from 0.88444
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 103s 429ms/step - accuracy: 0.8793 - loss: 0.2913 - val_accuracy: 0.8792 - val_loss: 0.3130 - learning_rate: 1.0000e-04
# Epoch 10/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.8918 - loss: 0.2691
# Epoch 10: val_accuracy improved from 0.88444 to 0.89172, saving model to best_vanilla_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 104s 430ms/step - accuracy: 0.8917 - loss: 0.2691 - val_accuracy: 0.8917 - val_loss: 0.3059 - learning_rate: 1.0000e-04
# Epoch 11/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.8893 - loss: 0.2618
# Epoch 11: val_accuracy improved from 0.89172 to 0.89328, saving model to best_vanilla_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 104s 432ms/step - accuracy: 0.8893 - loss: 0.2618 - val_accuracy: 0.8933 - val_loss: 0.2813 - learning_rate: 1.0000e-04
# Epoch 12/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.8889 - loss: 0.2641
# Epoch 12: val_accuracy improved from 0.89328 to 0.90578, saving model to best_vanilla_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 104s 433ms/step - accuracy: 0.8889 - loss: 0.2641 - val_accuracy: 0.9058 - val_loss: 0.2807 - learning_rate: 1.0000e-04
# Epoch 13/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.8887 - loss: 0.2664
# Epoch 13: val_accuracy did not improve from 0.90578
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 102s 425ms/step - accuracy: 0.8887 - loss: 0.2664 - val_accuracy: 0.8782 - val_loss: 0.2878 - learning_rate: 1.0000e-04
# Epoch 14/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.8814 - loss: 0.2727
# Epoch 14: val_accuracy did not improve from 0.90578
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 104s 433ms/step - accuracy: 0.8814 - loss: 0.2727 - val_accuracy: 0.8974 - val_loss: 0.2925 - learning_rate: 1.0000e-04
# Epoch 15/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.8914 - loss: 0.2569
# Epoch 15: val_accuracy did not improve from 0.90578
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 103s 429ms/step - accuracy: 0.8914 - loss: 0.2570 - val_accuracy: 0.8896 - val_loss: 0.2926 - learning_rate: 1.0000e-04
# Epoch 16/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.8967 - loss: 0.2378
# Epoch 16: val_accuracy did not improve from 0.90578
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 105s 435ms/step - accuracy: 0.8967 - loss: 0.2379 - val_accuracy: 0.8943 - val_loss: 0.2700 - learning_rate: 1.0000e-04
# Epoch 17/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.8854 - loss: 0.2600
# Epoch 17: val_accuracy did not improve from 0.90578
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 104s 432ms/step - accuracy: 0.8854 - loss: 0.2600 - val_accuracy: 0.8907 - val_loss: 0.2734 - learning_rate: 1.0000e-04
# Epoch 18/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9023 - loss: 0.2446
# Epoch 18: val_accuracy did not improve from 0.90578
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 104s 432ms/step - accuracy: 0.9023 - loss: 0.2447 - val_accuracy: 0.8959 - val_loss: 0.2753 - learning_rate: 1.0000e-04
# Epoch 19/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.8929 - loss: 0.2554
# Epoch 19: val_accuracy did not improve from 0.90578
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 105s 433ms/step - accuracy: 0.8929 - loss: 0.2554 - val_accuracy: 0.8839 - val_loss: 0.2884 - learning_rate: 1.0000e-04
# Epoch 20/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.8927 - loss: 0.2547
# Epoch 20: val_accuracy did not improve from 0.90578
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 103s 427ms/step - accuracy: 0.8927 - loss: 0.2547 - val_accuracy: 0.8896 - val_loss: 0.2907 - learning_rate: 1.0000e-04
# Epoch 21/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.8952 - loss: 0.2518
# Epoch 21: val_accuracy did not improve from 0.90578
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 106s 439ms/step - accuracy: 0.8952 - loss: 0.2518 - val_accuracy: 0.8865 - val_loss: 0.2843 - learning_rate: 1.0000e-04
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 16.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Training Finished.
# Model saved successfully!
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 21s 340ms/step - accuracy: 0.8889 - loss: 0.2875
# 0.27060264348983765 0.895887553691864
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 21s 338ms/step
#               precision    recall  f1-score   support
#
#       Benign       0.90      0.90      0.90      1000
#    Malignant       0.89      0.89      0.89       921
#
#     accuracy                           0.90      1921
#    macro avg       0.90      0.90      0.90      1921
# weighted avg       0.90      0.90      0.90      1921
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 150, 150, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 75, 75, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 75, 75, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 37, 37, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 37, 37, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 37, 37, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 18, 18, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 18, 18, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 18, 18, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 9, 9, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 9, 9, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 41472)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │     5,308,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,859,649 (26.17 MB)
#  Trainable params: 6,859,649 (26.17 MB)
#  Non-trainable params: 0 (0.00 B)
# Found 7684 images belonging to 2 classes.
# Found 1921 images belonging to 2 classes.
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 2026-04-06 15:15:35.272392: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-06 15:15:35.449477: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 174/241 ━━━━━━━━━━━━━━━━━━━━ 12s 190ms/step - accuracy: 0.6259 - loss: 0.6971
# 2026-04-06 15:16:16.004003: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-06 15:16:16.165444: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.6534 - loss: 0.6512
# Epoch 1: val_accuracy improved from -inf to 0.85789, saving model to best_cnn_ex2_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 78s 273ms/step - accuracy: 0.6538 - loss: 0.6506 - val_accuracy: 0.8579 - val_loss: 0.3847 - learning_rate: 0.0010
# Epoch 2/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.8421 - loss: 0.3614
# Epoch 2: val_accuracy improved from 0.85789 to 0.86101, saving model to best_cnn_ex2_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 57s 237ms/step - accuracy: 0.8421 - loss: 0.3613 - val_accuracy: 0.8610 - val_loss: 0.3151 - learning_rate: 0.0010
# Epoch 3/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.8536 - loss: 0.3270
# Epoch 3: val_accuracy did not improve from 0.86101
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 58s 239ms/step - accuracy: 0.8536 - loss: 0.3270 - val_accuracy: 0.8496 - val_loss: 0.3345 - learning_rate: 0.0010
# Epoch 4/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8587 - loss: 0.3329
# Epoch 4: val_accuracy improved from 0.86101 to 0.88600, saving model to best_cnn_ex2_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 59s 243ms/step - accuracy: 0.8587 - loss: 0.3329 - val_accuracy: 0.8860 - val_loss: 0.2700 - learning_rate: 0.0010
# Epoch 5/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.8734 - loss: 0.2887
# Epoch 5: val_accuracy did not improve from 0.88600
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 56s 233ms/step - accuracy: 0.8734 - loss: 0.2887 - val_accuracy: 0.8844 - val_loss: 0.2731 - learning_rate: 0.0010
# Epoch 6/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.8744 - loss: 0.2800
# Epoch 6: val_accuracy did not improve from 0.88600
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 56s 234ms/step - accuracy: 0.8744 - loss: 0.2801 - val_accuracy: 0.8704 - val_loss: 0.2956 - learning_rate: 0.0010
# Epoch 7/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.8784 - loss: 0.2852
# Epoch 7: val_accuracy improved from 0.88600 to 0.88808, saving model to best_cnn_ex2_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 56s 231ms/step - accuracy: 0.8783 - loss: 0.2852 - val_accuracy: 0.8881 - val_loss: 0.2778 - learning_rate: 0.0010
# Epoch 8/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.8758 - loss: 0.2783
# Epoch 8: val_accuracy improved from 0.88808 to 0.89641, saving model to best_cnn_ex2_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 57s 235ms/step - accuracy: 0.8758 - loss: 0.2783 - val_accuracy: 0.8964 - val_loss: 0.2637 - learning_rate: 0.0010
# Epoch 9/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.8844 - loss: 0.2728
# Epoch 9: val_accuracy improved from 0.89641 to 0.90109, saving model to best_cnn_ex2_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 58s 239ms/step - accuracy: 0.8844 - loss: 0.2728 - val_accuracy: 0.9011 - val_loss: 0.2820 - learning_rate: 0.0010
# Epoch 10/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.8857 - loss: 0.2645
# Epoch 10: val_accuracy did not improve from 0.90109
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 57s 235ms/step - accuracy: 0.8857 - loss: 0.2645 - val_accuracy: 0.8917 - val_loss: 0.2545 - learning_rate: 0.0010
# Epoch 11/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.8856 - loss: 0.2612
# Epoch 11: val_accuracy did not improve from 0.90109
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 56s 232ms/step - accuracy: 0.8856 - loss: 0.2612 - val_accuracy: 0.8631 - val_loss: 0.3161 - learning_rate: 0.0010
# Epoch 12/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.8864 - loss: 0.2564
# Epoch 12: val_accuracy did not improve from 0.90109
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 56s 232ms/step - accuracy: 0.8864 - loss: 0.2564 - val_accuracy: 0.8891 - val_loss: 0.2699 - learning_rate: 0.0010
# Epoch 13/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.8987 - loss: 0.2508
# Epoch 13: val_accuracy did not improve from 0.90109
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 57s 236ms/step - accuracy: 0.8987 - loss: 0.2508 - val_accuracy: 0.9011 - val_loss: 0.2501 - learning_rate: 0.0010
# Epoch 14/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.8938 - loss: 0.2594
# Epoch 14: val_accuracy did not improve from 0.90109
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 57s 236ms/step - accuracy: 0.8938 - loss: 0.2594 - val_accuracy: 0.8954 - val_loss: 0.2954 - learning_rate: 0.0010
# Epoch 15/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.8925 - loss: 0.2651
# Epoch 15: val_accuracy did not improve from 0.90109
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 56s 234ms/step - accuracy: 0.8925 - loss: 0.2651 - val_accuracy: 0.9011 - val_loss: 0.2393 - learning_rate: 0.0010
# Epoch 16/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.8893 - loss: 0.2550
# Epoch 16: val_accuracy did not improve from 0.90109
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 56s 232ms/step - accuracy: 0.8894 - loss: 0.2550 - val_accuracy: 0.8995 - val_loss: 0.2558 - learning_rate: 0.0010
# Epoch 17/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.8875 - loss: 0.2635
# Epoch 17: val_accuracy did not improve from 0.90109
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 55s 226ms/step - accuracy: 0.8874 - loss: 0.2635 - val_accuracy: 0.8907 - val_loss: 0.2666 - learning_rate: 0.0010
# Epoch 18/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.8926 - loss: 0.2491
# Epoch 18: val_accuracy improved from 0.90109 to 0.90734, saving model to best_cnn_ex2_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 55s 230ms/step - accuracy: 0.8927 - loss: 0.2491 - val_accuracy: 0.9073 - val_loss: 0.2376 - learning_rate: 0.0010
# Epoch 19/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9036 - loss: 0.2410
# Epoch 19: val_accuracy did not improve from 0.90734
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 55s 228ms/step - accuracy: 0.9036 - loss: 0.2410 - val_accuracy: 0.9027 - val_loss: 0.2400 - learning_rate: 0.0010
# Epoch 20/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.8961 - loss: 0.2492
# Epoch 20: val_accuracy did not improve from 0.90734
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 56s 232ms/step - accuracy: 0.8961 - loss: 0.2493 - val_accuracy: 0.8907 - val_loss: 0.2764 - learning_rate: 0.0010
# Epoch 21/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.8874 - loss: 0.2535
# Epoch 21: val_accuracy improved from 0.90734 to 0.91046, saving model to best_cnn_ex2_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 56s 230ms/step - accuracy: 0.8874 - loss: 0.2534 - val_accuracy: 0.9105 - val_loss: 0.2389 - learning_rate: 0.0010
# Epoch 22/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.8980 - loss: 0.2529
# Epoch 22: val_accuracy did not improve from 0.91046
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 56s 230ms/step - accuracy: 0.8981 - loss: 0.2529 - val_accuracy: 0.9079 - val_loss: 0.2250 - learning_rate: 0.0010
# Epoch 23/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9041 - loss: 0.2354
# Epoch 23: val_accuracy did not improve from 0.91046
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 56s 230ms/step - accuracy: 0.9041 - loss: 0.2354 - val_accuracy: 0.9016 - val_loss: 0.2391 - learning_rate: 0.0010
# Epoch 24/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9078 - loss: 0.2296
# Epoch 24: val_accuracy did not improve from 0.91046
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 56s 231ms/step - accuracy: 0.9079 - loss: 0.2296 - val_accuracy: 0.8959 - val_loss: 0.2647 - learning_rate: 0.0010
# Epoch 25/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9046 - loss: 0.2185
# Epoch 25: val_accuracy improved from 0.91046 to 0.91827, saving model to best_cnn_ex2_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 57s 235ms/step - accuracy: 0.9046 - loss: 0.2185 - val_accuracy: 0.9183 - val_loss: 0.2177 - learning_rate: 0.0010
# Epoch 26/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9065 - loss: 0.2206
# Epoch 26: val_accuracy improved from 0.91827 to 0.92140, saving model to best_cnn_ex2_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 57s 237ms/step - accuracy: 0.9065 - loss: 0.2206 - val_accuracy: 0.9214 - val_loss: 0.2119 - learning_rate: 0.0010
# Epoch 27/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9065 - loss: 0.2260
# Epoch 27: val_accuracy did not improve from 0.92140
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 56s 234ms/step - accuracy: 0.9065 - loss: 0.2260 - val_accuracy: 0.9001 - val_loss: 0.2400 - learning_rate: 0.0010
# Epoch 28/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9005 - loss: 0.2330
# Epoch 28: val_accuracy did not improve from 0.92140
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 56s 230ms/step - accuracy: 0.9005 - loss: 0.2329 - val_accuracy: 0.9099 - val_loss: 0.2306 - learning_rate: 0.0010
# Epoch 29/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9130 - loss: 0.2082
# Epoch 29: val_accuracy did not improve from 0.92140
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 55s 227ms/step - accuracy: 0.9129 - loss: 0.2082 - val_accuracy: 0.9136 - val_loss: 0.2231 - learning_rate: 0.0010
# Epoch 30/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9158 - loss: 0.2138
# Epoch 30: val_accuracy did not improve from 0.92140
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 55s 230ms/step - accuracy: 0.9157 - loss: 0.2138 - val_accuracy: 0.9089 - val_loss: 0.2247 - learning_rate: 0.0010
# Epoch 31/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9075 - loss: 0.2155
# Epoch 31: val_accuracy did not improve from 0.92140
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 56s 234ms/step - accuracy: 0.9075 - loss: 0.2155 - val_accuracy: 0.9125 - val_loss: 0.2260 - learning_rate: 0.0010
# Epoch 32/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9191 - loss: 0.1992
# Epoch 32: val_accuracy improved from 0.92140 to 0.92452, saving model to best_cnn_ex2_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 58s 239ms/step - accuracy: 0.9191 - loss: 0.1992 - val_accuracy: 0.9245 - val_loss: 0.1981 - learning_rate: 2.0000e-04
# Epoch 33/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9248 - loss: 0.1881
# Epoch 33: val_accuracy improved from 0.92452 to 0.92608, saving model to best_cnn_ex2_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 57s 235ms/step - accuracy: 0.9248 - loss: 0.1881 - val_accuracy: 0.9261 - val_loss: 0.2103 - learning_rate: 2.0000e-04
# Epoch 34/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9255 - loss: 0.1814
# Epoch 34: val_accuracy improved from 0.92608 to 0.92816, saving model to best_cnn_ex2_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 56s 233ms/step - accuracy: 0.9255 - loss: 0.1814 - val_accuracy: 0.9282 - val_loss: 0.1917 - learning_rate: 2.0000e-04
# Epoch 35/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9213 - loss: 0.1947
# Epoch 35: val_accuracy did not improve from 0.92816
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 56s 230ms/step - accuracy: 0.9213 - loss: 0.1947 - val_accuracy: 0.9271 - val_loss: 0.2029 - learning_rate: 2.0000e-04
# Epoch 36/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9261 - loss: 0.1795
# Epoch 36: val_accuracy did not improve from 0.92816
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 56s 231ms/step - accuracy: 0.9261 - loss: 0.1795 - val_accuracy: 0.9209 - val_loss: 0.2088 - learning_rate: 2.0000e-04
# Epoch 37/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9200 - loss: 0.1826
# Epoch 37: val_accuracy improved from 0.92816 to 0.93129, saving model to best_cnn_ex2_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 56s 233ms/step - accuracy: 0.9200 - loss: 0.1826 - val_accuracy: 0.9313 - val_loss: 0.1947 - learning_rate: 2.0000e-04
# Epoch 38/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9263 - loss: 0.1795
# Epoch 38: val_accuracy did not improve from 0.93129
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 55s 229ms/step - accuracy: 0.9263 - loss: 0.1795 - val_accuracy: 0.9292 - val_loss: 0.1956 - learning_rate: 2.0000e-04
# Epoch 39/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9205 - loss: 0.1867
# Epoch 39: val_accuracy did not improve from 0.93129
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 55s 230ms/step - accuracy: 0.9205 - loss: 0.1867 - val_accuracy: 0.9224 - val_loss: 0.2171 - learning_rate: 2.0000e-04
# Epoch 40/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9206 - loss: 0.1907
# Epoch 40: val_accuracy did not improve from 0.93129
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 57s 235ms/step - accuracy: 0.9206 - loss: 0.1906 - val_accuracy: 0.9250 - val_loss: 0.2059 - learning_rate: 4.0000e-05
# Epoch 41/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9266 - loss: 0.1746
# Epoch 41: val_accuracy did not improve from 0.93129
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 56s 234ms/step - accuracy: 0.9266 - loss: 0.1746 - val_accuracy: 0.9224 - val_loss: 0.2028 - learning_rate: 4.0000e-05
# Epoch 42/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9326 - loss: 0.1643
# Epoch 42: val_accuracy improved from 0.93129 to 0.93233, saving model to best_cnn_ex2_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 56s 231ms/step - accuracy: 0.9326 - loss: 0.1643 - val_accuracy: 0.9323 - val_loss: 0.1972 - learning_rate: 4.0000e-05
# Epoch 43/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9266 - loss: 0.1765
# Epoch 43: val_accuracy did not improve from 0.93233
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 56s 234ms/step - accuracy: 0.9266 - loss: 0.1765 - val_accuracy: 0.9282 - val_loss: 0.1947 - learning_rate: 4.0000e-05
# Epoch 44/50
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9244 - loss: 0.1743
# Epoch 44: val_accuracy did not improve from 0.93233
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1e-05.
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 57s 235ms/step - accuracy: 0.9244 - loss: 0.1743 - val_accuracy: 0.9313 - val_loss: 0.1971 - learning_rate: 4.0000e-05
# Epoch 44: early stopping
# Restoring model weights from the end of the best epoch: 34.
# ✅ Using dataset path: /kaggle/input/datasets/hasnainjaved/melanoma-skin-cancer-dataset-of-10000-images/melanoma_cancer_dataset/train
# Found 9605 images belonging to 2 classes.
# Predicting...
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 16s 51ms/step
#               precision    recall  f1-score   support
#
#       Benign       0.93      0.93      0.93      5000
#    Malignant       0.93      0.92      0.93      4605
#
#     accuracy                           0.93      9605
#    macro avg       0.93      0.93      0.93      9605
# weighted avg       0.93      0.93      0.93      9605
#
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224            │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1280)           │         5,120 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 512)            │       655,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,919,489 (11.14 MB)
#  Trainable params: 658,945 (2.51 MB)
#  Non-trainable params: 2,260,544 (8.62 MB)
# Epoch 1/20
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 120s 485ms/step - accuracy: 0.8204 - loss: 0.5099 - val_accuracy: 0.8870 - val_loss: 0.2907
# Epoch 2/20
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 119s 492ms/step - accuracy: 0.8730 - loss: 0.3265 - val_accuracy: 0.8714 - val_loss: 0.3109
# Epoch 3/20
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 118s 487ms/step - accuracy: 0.8849 - loss: 0.2821 - val_accuracy: 0.9001 - val_loss: 0.2600
# Epoch 4/20
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 115s 475ms/step - accuracy: 0.8799 - loss: 0.2892 - val_accuracy: 0.8959 - val_loss: 0.2571
# Epoch 5/20
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 114s 473ms/step - accuracy: 0.8951 - loss: 0.2569 - val_accuracy: 0.8990 - val_loss: 0.2365
# Epoch 6/20
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 114s 474ms/step - accuracy: 0.9008 - loss: 0.2435 - val_accuracy: 0.8922 - val_loss: 0.2656
# Epoch 7/20
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 116s 481ms/step - accuracy: 0.9030 - loss: 0.2402 - val_accuracy: 0.9011 - val_loss: 0.2389
# Epoch 8/20
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 115s 477ms/step - accuracy: 0.8990 - loss: 0.2430 - val_accuracy: 0.8974 - val_loss: 0.2454
# Epoch 9/20
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 117s 485ms/step - accuracy: 0.9072 - loss: 0.2314 - val_accuracy: 0.8974 - val_loss: 0.2495
# Epoch 10/20
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 118s 489ms/step - accuracy: 0.9080 - loss: 0.2257 - val_accuracy: 0.8995 - val_loss: 0.2472
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 5.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully!
# Generating predictions...
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 22s 361ms/step
#
# ✅ Model Accuracy: 90.27%
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#       benign       0.90      0.91      0.91      1000
#    malignant       0.90      0.89      0.90       921
#
#     accuracy                           0.90      1921
#    macro avg       0.90      0.90      0.90      1921
# weighted avg       0.90      0.90      0.90      1921
